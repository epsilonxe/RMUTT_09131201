# %% [markdown]
# # Workshop 02
#
# Root Finding

# %% [markdown]
# ## PROBLEM
#
# กําหนดฟังก์ชัน
#
# $$ f(x) = x^3 - 6x^2 + 11x - 5.9 $$
#
# จงหาค่ารากของสมการโดยวิธีกราฟ (Graphical Method)

# %%
# Solution here ...
from matplotlib import pyplot as plt

def f(x):
    y = x**3 - 6*x**2 + 11*x - 5.9
    return y


def myplot(f, xstart, xstop, xstep):
    range_x = [xstart, xstop]
    step_x = xstep
    x = range_x[0]
    list_x = []
    list_y = []
    while x <= range_x[1]:
        y = f(x)
        list_x.append(x)
        list_y.append(y)
        x = x + step_x

    plt.figure(figsize=(10,4), dpi=120)
    plt.plot(list_x, list_y)
    plt.grid()
    

myplot(f, 2.94550, 2.94575, 0.00001)

solution = 2.94565
print('Root of f is approximately', solution)
print(f'Check f({solution}) = {f(solution):.7f}')
# Out:
# Root of f is approximately 2.94565
# Check f(2.94565) = 0.0000012

# %% [markdown]
# ## PROBLEM
#
# กําหนดฟังก์ชัน
#
# $$ f(x) = x^3 - 6x^2 + 11x - 5.9 $$
#
# จงหาค่ารากของสมการโดยวิธีแบ่งครึ่งช่วง (Bisection Method)
#
# กำหนดค่าเริ่มต้น
#     $$ x_l = 2.5 \quad\text{ และ }\quad x_u = 3.5  $$
# โดยมีรอบการทำซ้ำ 10 รอบ

# %%
# Solution here ...

def is_this_solution(x):
    if f(xl)*f(xu) == 0:
        result = True
    else:
        result = False
    return result
        

    
print('ROOT FINDING: BOSECTION METHOD')

xl = 2.5
xu = 3.5

if f(xl)*f(xu) < 0:
    print('Condition OK!')
    while is_this_solution(xl, xu):
        xu = (xl + xu) / 2
        if f(xl)*f(xu) < 0:
            xu = 
else:
    print('Choose other xu or xl')
# Out:
#   File "/var/folders/d1/r7rwb7dx3nzbm5pb0tlf2h_40000gn/T/ipykernel_30356/2359177906.py", line 21
#     xu =
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## PROBLEM
#
# กําหนดฟังก์ชัน
#
# $$ f(x) = x^3 - 6x^2 + 11x - 5.9 $$
#
# จงหาค่ารากของสมการโดยวิธีแบ่งครึ่งช่วง (Bisection Method)
#
# กำหนดค่าเริ่มต้น
#     $$ x_l = 2.5 \quad\text{ และ }\quad x_u = 3.5  $$
# โดยที่ค่าร้อยละของความคลาดเคลื่อนสัมพัทธ์ คือ $\varepsilon_{s} = 0.1 \%$

# %%
# Solution here ...

# %% [markdown]
# ## PROBLEM
#
# กําหนดฟังก์ชัน
#
# $$ f(x) = x^3 - 6x^2 + 11x - 5.9 $$
#
# จงหาค่ารากของสมการโดยวิธีวางผิดที่ (False-Position Method)
#
# กำหนดค่าเริ่มต้น
#     $$ x_l = 2.5 \quad\text{ และ }\quad x_u = 3.5  $$
# โดยที่ค่าร้อยละของความคลาดเคลื่อนสัมพัทธ์ คือ $\varepsilon_{s} = 0.1 \%$

# %%
# Solution here ...

# %% [markdown]
# ## PROBLEM
#
# กําหนดฟังก์ชัน
#
# $$ f(x) = x^3 - 6x^2 + 11x - 5.9 $$
#
# จงหาค่ารากของสมการโดยวิธีนิวตันราฟสัน (Newton Raphson Method)
#
# กำหนดค่าเริ่มต้น
#     $$ x_0 = 3.5  $$
# โดยที่ค่าร้อยละของความคลาดเคลื่อนสัมพัทธ์ คือ $\varepsilon_{s} = 0.1 \%$

# %%
# Solution here ...

# %% [markdown]
# ## PROBLEM
#
# กําหนดฟังก์ชัน
#
# $$ f(x) = x^3 - 6x^2 + 11x - 5.9 $$
#
# จงหาค่ารากของสมการโดยวิธีทำซ้ำแบบจุดตรึง (Fixed-Point Iteration Method)
#
# กำหนดค่าเริ่มต้น
#     $$ x_0 = 3.5  $$
# โดยที่ค่าร้อยละของความคลาดเคลื่อนสัมพัทธ์ คือ $\varepsilon_{s} = 0.1 \%$

# %%
# Solution here ...
